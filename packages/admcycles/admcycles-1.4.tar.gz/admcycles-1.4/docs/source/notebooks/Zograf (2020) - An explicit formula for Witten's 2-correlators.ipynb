# %% [markdown]
# # Zograf (2020) - An explicit formula for Witten's 2-correlators
# We check the results of [[Zograf 20]](https://arxiv.org/abs/2012.03268) in some particular examples.

# %%
from admcycles import *
from admcycles.stratarecursion import classes

# %% [markdown]
# For preparation, we define a function which returns the double factorial.

# %%
def doublefactorial(m):
    return ZZ(m).multifactorial(2)

# %% [markdown]
# We define the function ``number_b(g,k)`` which computes the numbers $b_{g,k}$ given in the Lemma of [[Zograf 20]](https://arxiv.org/abs/2012.03268), equation 7.

# %%
def number_b(g,k):
    if k < floor((3*g-1)/2) and k>=0 and g>=0:
        if mod(k,3) == 0:
            j = (k/3);
            pf = doublefactorial(6*g-3-2*k)/doublefactorial(6*g-1); #pf is a shorthand for prefactor
            return pf*(-2)*(doublefactorial(6*j+1)/factorial(j))*(factorial(g-1)/factorial(g-1-j))
        if mod(k,3) == 1:
            j = floor(k/3-1/3);
            pf = doublefactorial(6*g-3-2*k)/doublefactorial(6*g-1);
            return pf*2*(doublefactorial(6*j+3)/factorial(j))*(factorial(g-1)/factorial(g-1-j))
        if mod(k,3) == 2:
            j = floor(k/3+1/3);
            pf = doublefactorial(6*g-3-2*k)/doublefactorial(6*g-1);
            return pf*(doublefactorial(6*j-1)/factorial(j))*((factorial(g-1))/(factorial(g-j)))*(g-2*j)
    else:
        raise ValueError('k must be in [0,...[(3g-1)/2]] and g >=0')

# %% [markdown]
# This function returns the sum $\sum_{i=1}^{k-1} b_{g,i}$ appearing in the main theorem of [[Zograf 20]](https://arxiv.org/abs/2012.03268), equation 8.

# %%
def sum_b(g,k):
    if k < floor((3*g-1)/2) and k>1 and g>=0:
        return sum(number_b(g,i) for i in range(1,k))
    else: 
        raise ValueError('k must be in [2,...[(3g-1)/2]] and g >=0')

# %% [markdown]
# We define the two correlator expression which appears in the main theorem of [[Zograf 20]](https://arxiv.org/abs/2012.03268), equation 8.

# %%
def two_correlators(g,k):
    if k < floor((3*g-1)/2) and k>1 and g>=0:
        return (doublefactorial(6*g-1)/(24**g*factorial(g)*doublefactorial(2*k+1)*doublefactorial(6*g-1-2*k)))*((6*g-3)/(6*g-1) + sum_b(g,k))
    else:
        print('k is in [2,...[(3g-1)/2]] and g >=0')

# %% [markdown]
# The two correlator expression in the main theorem of [[Zograf 20]](https://arxiv.org/abs/2012.03268), equation 8 can also be computed through
#
# \begin{align*}
# \langle \tau_{k} \tau_{3g-1-k} \rangle
# =
# \int_{\bar{\mathcal{M}}_{g,2}} \psi_1^{k} \psi_2^{3g-1-k}
# \end{align*}
#
# Next, we define this function and compare the two expression in certain examples.

# %%
def two_correlators_psi(g,k):
    if k < floor((3*g-1)/2) and k>1 and g>=0:
        C = psiclass(1,g,2)**k*psiclass(2,g,2)**(3*g-1-k);
        return C.evaluate()
    else:
        raise ValueError('k must be in [2,...[(3g-1)/2]] and g >=0')

# %% [markdown]
# For $g \in [2,\ldots,30]$ , we create a list of tuples of the form $(g,k)$ where $k \in [2\,, \ldots ,\left[\frac{3g-1}{2} \right] -1]$

# %%
test = [];
for i in range(2,30):
    for j in range(2,floor((3*i-1)/2)):
        test.append((i,j))

# %% [markdown]
# We test the equality in the main theorem of the paper, by evaluating the difference of the two sides. If their difference is not 0 for some (g,k) it returns: "equality does not hold"

# %%
for j in test:
    (g,k) = j;
    diff = two_correlators(g,k) - two_correlators_psi(g,k);
    if diff != 0:
        print('equality does not hold')
        break
    else:
        print(f"equality holds for (g,k)={j}")
# Out:
# equality holds for (g,k)=(3, 2)
# equality holds for (g,k)=(3, 3)
# equality holds for (g,k)=(4, 2)
# equality holds for (g,k)=(4, 3)
# equality holds for (g,k)=(4, 4)
# equality holds for (g,k)=(5, 2)
# equality holds for (g,k)=(5, 3)
# equality holds for (g,k)=(5, 4)
# equality holds for (g,k)=(5, 5)
# equality holds for (g,k)=(5, 6)
# equality holds for (g,k)=(6, 2)
# equality holds for (g,k)=(6, 3)
# equality holds for (g,k)=(6, 4)
# equality holds for (g,k)=(6, 5)
# equality holds for (g,k)=(6, 6)
# equality holds for (g,k)=(6, 7)
# equality holds for (g,k)=(7, 2)
# equality holds for (g,k)=(7, 3)
# equality holds for (g,k)=(7, 4)
# equality holds for (g,k)=(7, 5)
# equality holds for (g,k)=(7, 6)
# equality holds for (g,k)=(7, 7)
# equality holds for (g,k)=(7, 8)
# equality holds for (g,k)=(7, 9)
# equality holds for (g,k)=(8, 2)
# equality holds for (g,k)=(8, 3)
# equality holds for (g,k)=(8, 4)
# equality holds for (g,k)=(8, 5)
# equality holds for (g,k)=(8, 6)
# equality holds for (g,k)=(8, 7)
# equality holds for (g,k)=(8, 8)
# equality holds for (g,k)=(8, 9)
# equality holds for (g,k)=(8, 10)
# equality holds for (g,k)=(9, 2)
# equality holds for (g,k)=(9, 3)
# equality holds for (g,k)=(9, 4)
# equality holds for (g,k)=(9, 5)
# equality holds for (g,k)=(9, 6)
# equality holds for (g,k)=(9, 7)
# equality holds for (g,k)=(9, 8)
# equality holds for (g,k)=(9, 9)
# equality holds for (g,k)=(9, 10)
# equality holds for (g,k)=(9, 11)
# equality holds for (g,k)=(9, 12)
# equality holds for (g,k)=(10, 2)
# equality holds for (g,k)=(10, 3)
# equality holds for (g,k)=(10, 4)
# equality holds for (g,k)=(10, 5)
# equality holds for (g,k)=(10, 6)
# equality holds for (g,k)=(10, 7)
# equality holds for (g,k)=(10, 8)
# equality holds for (g,k)=(10, 9)
# equality holds for (g,k)=(10, 10)
# equality holds for (g,k)=(10, 11)
# equality holds for (g,k)=(10, 12)
# equality holds for (g,k)=(10, 13)
# equality holds for (g,k)=(11, 2)
# equality holds for (g,k)=(11, 3)
# equality holds for (g,k)=(11, 4)
# equality holds for (g,k)=(11, 5)
# equality holds for (g,k)=(11, 6)
# equality holds for (g,k)=(11, 7)
# equality holds for (g,k)=(11, 8)
# equality holds for (g,k)=(11, 9)
# equality holds for (g,k)=(11, 10)
# equality holds for (g,k)=(11, 11)
# equality holds for (g,k)=(11, 12)
# equality holds for (g,k)=(11, 13)
# equality holds for (g,k)=(11, 14)
# equality holds for (g,k)=(11, 15)
# equality holds for (g,k)=(12, 2)
# equality holds for (g,k)=(12, 3)
# equality holds for (g,k)=(12, 4)
# equality holds for (g,k)=(12, 5)
# equality holds for (g,k)=(12, 6)
# equality holds for (g,k)=(12, 7)
# equality holds for (g,k)=(12, 8)
# equality holds for (g,k)=(12, 9)
# equality holds for (g,k)=(12, 10)
# equality holds for (g,k)=(12, 11)
# equality holds for (g,k)=(12, 12)
# equality holds for (g,k)=(12, 13)
# equality holds for (g,k)=(12, 14)
# equality holds for (g,k)=(12, 15)
# equality holds for (g,k)=(12, 16)
# equality holds for (g,k)=(13, 2)
# equality holds for (g,k)=(13, 3)
# equality holds for (g,k)=(13, 4)
# equality holds for (g,k)=(13, 5)
# equality holds for (g,k)=(13, 6)
# equality holds for (g,k)=(13, 7)
# equality holds for (g,k)=(13, 8)
# equality holds for (g,k)=(13, 9)
# equality holds for (g,k)=(13, 10)
# equality holds for (g,k)=(13, 11)
# equality holds for (g,k)=(13, 12)
# equality holds for (g,k)=(13, 13)
# equality holds for (g,k)=(13, 14)
# equality holds for (g,k)=(13, 15)
# equality holds for (g,k)=(13, 16)
# equality holds for (g,k)=(13, 17)
# equality holds for (g,k)=(13, 18)
# equality holds for (g,k)=(14, 2)
# equality holds for (g,k)=(14, 3)
# equality holds for (g,k)=(14, 4)
# equality holds for (g,k)=(14, 5)
# equality holds for (g,k)=(14, 6)
# equality holds for (g,k)=(14, 7)
# equality holds for (g,k)=(14, 8)
# equality holds for (g,k)=(14, 9)
# equality holds for (g,k)=(14, 10)
# equality holds for (g,k)=(14, 11)
# equality holds for (g,k)=(14, 12)
# equality holds for (g,k)=(14, 13)
# equality holds for (g,k)=(14, 14)
# equality holds for (g,k)=(14, 15)
# equality holds for (g,k)=(14, 16)
# equality holds for (g,k)=(14, 17)
# equality holds for (g,k)=(14, 18)
# equality holds for (g,k)=(14, 19)
# equality holds for (g,k)=(15, 2)
# equality holds for (g,k)=(15, 3)
# equality holds for (g,k)=(15, 4)
# equality holds for (g,k)=(15, 5)
# equality holds for (g,k)=(15, 6)
# equality holds for (g,k)=(15, 7)
# equality holds for (g,k)=(15, 8)
# equality holds for (g,k)=(15, 9)
# equality holds for (g,k)=(15, 10)
# equality holds for (g,k)=(15, 11)
# equality holds for (g,k)=(15, 12)
# equality holds for (g,k)=(15, 13)
# equality holds for (g,k)=(15, 14)
# equality holds for (g,k)=(15, 15)
# equality holds for (g,k)=(15, 16)
# equality holds for (g,k)=(15, 17)
# equality holds for (g,k)=(15, 18)
# equality holds for (g,k)=(15, 19)
# equality holds for (g,k)=(15, 20)
# equality holds for (g,k)=(15, 21)
# equality holds for (g,k)=(16, 2)
# equality holds for (g,k)=(16, 3)
# equality holds for (g,k)=(16, 4)
# equality holds for (g,k)=(16, 5)
# equality holds for (g,k)=(16, 6)
# equality holds for (g,k)=(16, 7)
# equality holds for (g,k)=(16, 8)
# equality holds for (g,k)=(16, 9)
# equality holds for (g,k)=(16, 10)
# equality holds for (g,k)=(16, 11)
# equality holds for (g,k)=(16, 12)
# equality holds for (g,k)=(16, 13)
# equality holds for (g,k)=(16, 14)
# equality holds for (g,k)=(16, 15)
# equality holds for (g,k)=(16, 16)
# equality holds for (g,k)=(16, 17)
# equality holds for (g,k)=(16, 18)
# equality holds for (g,k)=(16, 19)
# equality holds for (g,k)=(16, 20)
# equality holds for (g,k)=(16, 21)
# equality holds for (g,k)=(16, 22)
# equality holds for (g,k)=(17, 2)
# equality holds for (g,k)=(17, 3)
# equality holds for (g,k)=(17, 4)
# equality holds for (g,k)=(17, 5)
# equality holds for (g,k)=(17, 6)
# equality holds for (g,k)=(17, 7)
# equality holds for (g,k)=(17, 8)
# equality holds for (g,k)=(17, 9)
# equality holds for (g,k)=(17, 10)
# equality holds for (g,k)=(17, 11)
# equality holds for (g,k)=(17, 12)
# equality holds for (g,k)=(17, 13)
# equality holds for (g,k)=(17, 14)
# equality holds for (g,k)=(17, 15)
# equality holds for (g,k)=(17, 16)
# equality holds for (g,k)=(17, 17)
# equality holds for (g,k)=(17, 18)
# equality holds for (g,k)=(17, 19)
# equality holds for (g,k)=(17, 20)
# equality holds for (g,k)=(17, 21)
# equality holds for (g,k)=(17, 22)
# equality holds for (g,k)=(17, 23)
# equality holds for (g,k)=(17, 24)
# equality holds for (g,k)=(18, 2)
# equality holds for (g,k)=(18, 3)
# equality holds for (g,k)=(18, 4)
# equality holds for (g,k)=(18, 5)
# equality holds for (g,k)=(18, 6)
# equality holds for (g,k)=(18, 7)
# equality holds for (g,k)=(18, 8)
# equality holds for (g,k)=(18, 9)
# equality holds for (g,k)=(18, 10)
# equality holds for (g,k)=(18, 11)
# equality holds for (g,k)=(18, 12)
# equality holds for (g,k)=(18, 13)
# equality holds for (g,k)=(18, 14)
# equality holds for (g,k)=(18, 15)
# equality holds for (g,k)=(18, 16)
# equality holds for (g,k)=(18, 17)
# equality holds for (g,k)=(18, 18)
# equality holds for (g,k)=(18, 19)
# equality holds for (g,k)=(18, 20)
# equality holds for (g,k)=(18, 21)
# equality holds for (g,k)=(18, 22)
# equality holds for (g,k)=(18, 23)
# equality holds for (g,k)=(18, 24)
# equality holds for (g,k)=(18, 25)
# equality holds for (g,k)=(19, 2)
# equality holds for (g,k)=(19, 3)
# equality holds for (g,k)=(19, 4)
# equality holds for (g,k)=(19, 5)
# equality holds for (g,k)=(19, 6)
# equality holds for (g,k)=(19, 7)
# equality holds for (g,k)=(19, 8)
# equality holds for (g,k)=(19, 9)
# equality holds for (g,k)=(19, 10)
# equality holds for (g,k)=(19, 11)
# equality holds for (g,k)=(19, 12)
# equality holds for (g,k)=(19, 13)
# equality holds for (g,k)=(19, 14)
# equality holds for (g,k)=(19, 15)
# equality holds for (g,k)=(19, 16)
# equality holds for (g,k)=(19, 17)
# equality holds for (g,k)=(19, 18)
# equality holds for (g,k)=(19, 19)
# equality holds for (g,k)=(19, 20)
# equality holds for (g,k)=(19, 21)
# equality holds for (g,k)=(19, 22)
# equality holds for (g,k)=(19, 23)
# equality holds for (g,k)=(19, 24)
# equality holds for (g,k)=(19, 25)
# equality holds for (g,k)=(19, 26)
# equality holds for (g,k)=(19, 27)
# equality holds for (g,k)=(20, 2)
# equality holds for (g,k)=(20, 3)
# equality holds for (g,k)=(20, 4)
# equality holds for (g,k)=(20, 5)
# equality holds for (g,k)=(20, 6)
# equality holds for (g,k)=(20, 7)
# equality holds for (g,k)=(20, 8)
# equality holds for (g,k)=(20, 9)
# equality holds for (g,k)=(20, 10)
# equality holds for (g,k)=(20, 11)
# equality holds for (g,k)=(20, 12)
# equality holds for (g,k)=(20, 13)
# equality holds for (g,k)=(20, 14)
# equality holds for (g,k)=(20, 15)
# equality holds for (g,k)=(20, 16)
# equality holds for (g,k)=(20, 17)
# equality holds for (g,k)=(20, 18)
# equality holds for (g,k)=(20, 19)
# equality holds for (g,k)=(20, 20)
# equality holds for (g,k)=(20, 21)
# equality holds for (g,k)=(20, 22)
# equality holds for (g,k)=(20, 23)
# equality holds for (g,k)=(20, 24)
# equality holds for (g,k)=(20, 25)
# equality holds for (g,k)=(20, 26)
# equality holds for (g,k)=(20, 27)
# equality holds for (g,k)=(20, 28)
# equality holds for (g,k)=(21, 2)
# equality holds for (g,k)=(21, 3)
# equality holds for (g,k)=(21, 4)
# equality holds for (g,k)=(21, 5)
# equality holds for (g,k)=(21, 6)
# equality holds for (g,k)=(21, 7)
# equality holds for (g,k)=(21, 8)
# equality holds for (g,k)=(21, 9)
# equality holds for (g,k)=(21, 10)
# equality holds for (g,k)=(21, 11)
# equality holds for (g,k)=(21, 12)
# equality holds for (g,k)=(21, 13)
# equality holds for (g,k)=(21, 14)
# equality holds for (g,k)=(21, 15)
# equality holds for (g,k)=(21, 16)
# equality holds for (g,k)=(21, 17)
# equality holds for (g,k)=(21, 18)
# equality holds for (g,k)=(21, 19)
# equality holds for (g,k)=(21, 20)
# equality holds for (g,k)=(21, 21)
# equality holds for (g,k)=(21, 22)
# equality holds for (g,k)=(21, 23)
# equality holds for (g,k)=(21, 24)
# equality holds for (g,k)=(21, 25)
# equality holds for (g,k)=(21, 26)
# equality holds for (g,k)=(21, 27)
# equality holds for (g,k)=(21, 28)
# equality holds for (g,k)=(21, 29)
# equality holds for (g,k)=(21, 30)
# equality holds for (g,k)=(22, 2)
# equality holds for (g,k)=(22, 3)
# equality holds for (g,k)=(22, 4)
# equality holds for (g,k)=(22, 5)
# equality holds for (g,k)=(22, 6)
# equality holds for (g,k)=(22, 7)
# equality holds for (g,k)=(22, 8)
# equality holds for (g,k)=(22, 9)
# equality holds for (g,k)=(22, 10)
# equality holds for (g,k)=(22, 11)
# equality holds for (g,k)=(22, 12)
# equality holds for (g,k)=(22, 13)
# equality holds for (g,k)=(22, 14)
# equality holds for (g,k)=(22, 15)
# equality holds for (g,k)=(22, 16)
# equality holds for (g,k)=(22, 17)
# equality holds for (g,k)=(22, 18)
# equality holds for (g,k)=(22, 19)
# equality holds for (g,k)=(22, 20)
# equality holds for (g,k)=(22, 21)
# equality holds for (g,k)=(22, 22)
# equality holds for (g,k)=(22, 23)
# equality holds for (g,k)=(22, 24)
# equality holds for (g,k)=(22, 25)
# equality holds for (g,k)=(22, 26)
# equality holds for (g,k)=(22, 27)
# equality holds for (g,k)=(22, 28)
# equality holds for (g,k)=(22, 29)
# equality holds for (g,k)=(22, 30)
# equality holds for (g,k)=(22, 31)
# equality holds for (g,k)=(23, 2)
# equality holds for (g,k)=(23, 3)
# equality holds for (g,k)=(23, 4)
# equality holds for (g,k)=(23, 5)
# equality holds for (g,k)=(23, 6)
# equality holds for (g,k)=(23, 7)
# equality holds for (g,k)=(23, 8)
# equality holds for (g,k)=(23, 9)
# equality holds for (g,k)=(23, 10)
# equality holds for (g,k)=(23, 11)
# equality holds for (g,k)=(23, 12)
# equality holds for (g,k)=(23, 13)
# equality holds for (g,k)=(23, 14)
# equality holds for (g,k)=(23, 15)
# equality holds for (g,k)=(23, 16)
# equality holds for (g,k)=(23, 17)
# equality holds for (g,k)=(23, 18)
# equality holds for (g,k)=(23, 19)
# equality holds for (g,k)=(23, 20)
# equality holds for (g,k)=(23, 21)
# equality holds for (g,k)=(23, 22)
# equality holds for (g,k)=(23, 23)
# equality holds for (g,k)=(23, 24)
# equality holds for (g,k)=(23, 25)
# equality holds for (g,k)=(23, 26)
# equality holds for (g,k)=(23, 27)
# equality holds for (g,k)=(23, 28)
# equality holds for (g,k)=(23, 29)
# equality holds for (g,k)=(23, 30)
# equality holds for (g,k)=(23, 31)
# equality holds for (g,k)=(23, 32)
# equality holds for (g,k)=(23, 33)
# equality holds for (g,k)=(24, 2)
# equality holds for (g,k)=(24, 3)
# equality holds for (g,k)=(24, 4)
# equality holds for (g,k)=(24, 5)
# equality holds for (g,k)=(24, 6)
# equality holds for (g,k)=(24, 7)
# equality holds for (g,k)=(24, 8)
# equality holds for (g,k)=(24, 9)
# equality holds for (g,k)=(24, 10)
# equality holds for (g,k)=(24, 11)
# equality holds for (g,k)=(24, 12)
# equality holds for (g,k)=(24, 13)
# equality holds for (g,k)=(24, 14)
# equality holds for (g,k)=(24, 15)
# equality holds for (g,k)=(24, 16)
# equality holds for (g,k)=(24, 17)
# equality holds for (g,k)=(24, 18)
# equality holds for (g,k)=(24, 19)
# equality holds for (g,k)=(24, 20)
# equality holds for (g,k)=(24, 21)
# equality holds for (g,k)=(24, 22)
# equality holds for (g,k)=(24, 23)
# equality holds for (g,k)=(24, 24)
# equality holds for (g,k)=(24, 25)
# equality holds for (g,k)=(24, 26)
# equality holds for (g,k)=(24, 27)
# equality holds for (g,k)=(24, 28)
# equality holds for (g,k)=(24, 29)
# equality holds for (g,k)=(24, 30)
# equality holds for (g,k)=(24, 31)
# equality holds for (g,k)=(24, 32)
# equality holds for (g,k)=(24, 33)
# equality holds for (g,k)=(24, 34)
# equality holds for (g,k)=(25, 2)
# equality holds for (g,k)=(25, 3)
# equality holds for (g,k)=(25, 4)
# equality holds for (g,k)=(25, 5)
# equality holds for (g,k)=(25, 6)
# equality holds for (g,k)=(25, 7)
# equality holds for (g,k)=(25, 8)
# equality holds for (g,k)=(25, 9)
# equality holds for (g,k)=(25, 10)
# equality holds for (g,k)=(25, 11)
# equality holds for (g,k)=(25, 12)
# equality holds for (g,k)=(25, 13)
# equality holds for (g,k)=(25, 14)
# equality holds for (g,k)=(25, 15)
# equality holds for (g,k)=(25, 16)
# equality holds for (g,k)=(25, 17)
# equality holds for (g,k)=(25, 18)
# equality holds for (g,k)=(25, 19)
# equality holds for (g,k)=(25, 20)
# equality holds for (g,k)=(25, 21)
# equality holds for (g,k)=(25, 22)
# equality holds for (g,k)=(25, 23)
# equality holds for (g,k)=(25, 24)
# equality holds for (g,k)=(25, 25)
# equality holds for (g,k)=(25, 26)
# equality holds for (g,k)=(25, 27)
# equality holds for (g,k)=(25, 28)
# equality holds for (g,k)=(25, 29)
# equality holds for (g,k)=(25, 30)
# equality holds for (g,k)=(25, 31)
# equality holds for (g,k)=(25, 32)
# equality holds for (g,k)=(25, 33)
# equality holds for (g,k)=(25, 34)
# equality holds for (g,k)=(25, 35)
# equality holds for (g,k)=(25, 36)
# equality holds for (g,k)=(26, 2)
# equality holds for (g,k)=(26, 3)
# equality holds for (g,k)=(26, 4)
# equality holds for (g,k)=(26, 5)
# equality holds for (g,k)=(26, 6)
# equality holds for (g,k)=(26, 7)
# equality holds for (g,k)=(26, 8)
# equality holds for (g,k)=(26, 9)
# equality holds for (g,k)=(26, 10)
# equality holds for (g,k)=(26, 11)
# equality holds for (g,k)=(26, 12)
# equality holds for (g,k)=(26, 13)
# equality holds for (g,k)=(26, 14)
# equality holds for (g,k)=(26, 15)
# equality holds for (g,k)=(26, 16)
# equality holds for (g,k)=(26, 17)
# equality holds for (g,k)=(26, 18)
# equality holds for (g,k)=(26, 19)
# equality holds for (g,k)=(26, 20)
# equality holds for (g,k)=(26, 21)
# equality holds for (g,k)=(26, 22)
# equality holds for (g,k)=(26, 23)
# equality holds for (g,k)=(26, 24)
# equality holds for (g,k)=(26, 25)
# equality holds for (g,k)=(26, 26)
# equality holds for (g,k)=(26, 27)
# equality holds for (g,k)=(26, 28)
# equality holds for (g,k)=(26, 29)
# equality holds for (g,k)=(26, 30)
# equality holds for (g,k)=(26, 31)
# equality holds for (g,k)=(26, 32)
# equality holds for (g,k)=(26, 33)
# equality holds for (g,k)=(26, 34)
# equality holds for (g,k)=(26, 35)
# equality holds for (g,k)=(26, 36)
# equality holds for (g,k)=(26, 37)
# equality holds for (g,k)=(27, 2)
# equality holds for (g,k)=(27, 3)
# equality holds for (g,k)=(27, 4)
# equality holds for (g,k)=(27, 5)
# equality holds for (g,k)=(27, 6)
# equality holds for (g,k)=(27, 7)
# equality holds for (g,k)=(27, 8)
# equality holds for (g,k)=(27, 9)
# equality holds for (g,k)=(27, 10)
# equality holds for (g,k)=(27, 11)
# equality holds for (g,k)=(27, 12)
# equality holds for (g,k)=(27, 13)
# equality holds for (g,k)=(27, 14)
# equality holds for (g,k)=(27, 15)
# equality holds for (g,k)=(27, 16)
# equality holds for (g,k)=(27, 17)
# equality holds for (g,k)=(27, 18)
# equality holds for (g,k)=(27, 19)
# equality holds for (g,k)=(27, 20)
# equality holds for (g,k)=(27, 21)
# equality holds for (g,k)=(27, 22)
# equality holds for (g,k)=(27, 23)
# equality holds for (g,k)=(27, 24)
# equality holds for (g,k)=(27, 25)
# equality holds for (g,k)=(27, 26)
# equality holds for (g,k)=(27, 27)
# equality holds for (g,k)=(27, 28)
# equality holds for (g,k)=(27, 29)
# equality holds for (g,k)=(27, 30)
# equality holds for (g,k)=(27, 31)
# equality holds for (g,k)=(27, 32)
# equality holds for (g,k)=(27, 33)
# equality holds for (g,k)=(27, 34)
# equality holds for (g,k)=(27, 35)
# equality holds for (g,k)=(27, 36)
# equality holds for (g,k)=(27, 37)
# equality holds for (g,k)=(27, 38)
# equality holds for (g,k)=(27, 39)
# equality holds for (g,k)=(28, 2)
# equality holds for (g,k)=(28, 3)
# equality holds for (g,k)=(28, 4)
# equality holds for (g,k)=(28, 5)
# equality holds for (g,k)=(28, 6)
# equality holds for (g,k)=(28, 7)
# equality holds for (g,k)=(28, 8)
# equality holds for (g,k)=(28, 9)
# equality holds for (g,k)=(28, 10)
# equality holds for (g,k)=(28, 11)
# equality holds for (g,k)=(28, 12)
# equality holds for (g,k)=(28, 13)
# equality holds for (g,k)=(28, 14)
# equality holds for (g,k)=(28, 15)
# equality holds for (g,k)=(28, 16)
# equality holds for (g,k)=(28, 17)
# equality holds for (g,k)=(28, 18)
# equality holds for (g,k)=(28, 19)
# equality holds for (g,k)=(28, 20)
# equality holds for (g,k)=(28, 21)
# equality holds for (g,k)=(28, 22)
# equality holds for (g,k)=(28, 23)
# equality holds for (g,k)=(28, 24)
# equality holds for (g,k)=(28, 25)
# equality holds for (g,k)=(28, 26)
# equality holds for (g,k)=(28, 27)
# equality holds for (g,k)=(28, 28)
# equality holds for (g,k)=(28, 29)
# equality holds for (g,k)=(28, 30)
# equality holds for (g,k)=(28, 31)
# equality holds for (g,k)=(28, 32)
# equality holds for (g,k)=(28, 33)
# equality holds for (g,k)=(28, 34)
# equality holds for (g,k)=(28, 35)
# equality holds for (g,k)=(28, 36)
# equality holds for (g,k)=(28, 37)
# equality holds for (g,k)=(28, 38)
# equality holds for (g,k)=(28, 39)
# equality holds for (g,k)=(28, 40)
# equality holds for (g,k)=(29, 2)
# equality holds for (g,k)=(29, 3)
# equality holds for (g,k)=(29, 4)
# equality holds for (g,k)=(29, 5)
# equality holds for (g,k)=(29, 6)
# equality holds for (g,k)=(29, 7)
# equality holds for (g,k)=(29, 8)
# equality holds for (g,k)=(29, 9)
# equality holds for (g,k)=(29, 10)
# equality holds for (g,k)=(29, 11)
# equality holds for (g,k)=(29, 12)
# equality holds for (g,k)=(29, 13)
# equality holds for (g,k)=(29, 14)
# equality holds for (g,k)=(29, 15)
# equality holds for (g,k)=(29, 16)
# equality holds for (g,k)=(29, 17)
# equality holds for (g,k)=(29, 18)
# equality holds for (g,k)=(29, 19)
# equality holds for (g,k)=(29, 20)
# equality holds for (g,k)=(29, 21)
# equality holds for (g,k)=(29, 22)
# equality holds for (g,k)=(29, 23)
# equality holds for (g,k)=(29, 24)
# equality holds for (g,k)=(29, 25)
# equality holds for (g,k)=(29, 26)
# equality holds for (g,k)=(29, 27)
# equality holds for (g,k)=(29, 28)
# equality holds for (g,k)=(29, 29)
# equality holds for (g,k)=(29, 30)
# equality holds for (g,k)=(29, 31)
# equality holds for (g,k)=(29, 32)
# equality holds for (g,k)=(29, 33)
# equality holds for (g,k)=(29, 34)
# equality holds for (g,k)=(29, 35)
# equality holds for (g,k)=(29, 36)
# equality holds for (g,k)=(29, 37)
# equality holds for (g,k)=(29, 38)
# equality holds for (g,k)=(29, 39)
# equality holds for (g,k)=(29, 40)
# equality holds for (g,k)=(29, 41)
# equality holds for (g,k)=(29, 42)
